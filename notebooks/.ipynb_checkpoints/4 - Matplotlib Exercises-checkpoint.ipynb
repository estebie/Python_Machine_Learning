# %% [markdown]
# **Data**

# %%
import numpy as np
x = np.arange(0, 100)
y = x*2
z = x**2

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# **1.**
# * ** Create a figure object called fig using plt.figure() **
# * ** Use add_axes to add an axis to the figure canvas at [0,0,1,1]. Call this new axis ax. **
# * ** Plot (x,y) on that axes and set the labels and titles to match the plot below:**

# %%
fig = plt.figure()
axes = fig.add_axes([0,0,1,1])
axes.plot(x, y, 'b')
axes.set_title('title')
axes.set_xlabel('x')
axes.set_ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# **2.** Create a figure object and put two axes on it, ax1 and ax2. Located at [0,0,1,1] and [0.2,0.5,.2,.2] respectively.

# %%
fig = plt.figure()
axes1 = fig.add_axes([0,0,1,1])
axes2 = fig.add_axes([0.2,0.5,0.2,0.2])

# %% [markdown]
# Now plot (x,y) on both axes. And call your figure object to show it.

# %%
axes1.plot(x, y, 'r')
axes1.set_title('title')
axes1.set_xlabel('x')
axes1.set_ylabel('y')

axes2.plot(x,y, 'r')
axes2.set_title('title')
axes2.set_xlabel('x')
axes2.set_ylabel('y')
fig

# %% [markdown]
# **2.** Create a figure object and put two axes on it, ax1 and ax2. Located at [0,0,1,1] and [0.2,0.5,.4,.4] respectively.

# %%
fig = plt.figure()
axes1 = fig.add_axes([0,0,1,1])
axes2 = fig.add_axes([0.2,0.5,.4,.4])
